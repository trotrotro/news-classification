# %%
import pandas as pd

train_df = pd.read_csv("../data/rus_news_data/train.csv")

train_df.head()
# Out:
#    Unnamed: 0                                               text  \
# 0        3102  В Северной Осетии на создание дополнительных м...
# 1         495  Двукратный олимпийский чемпион  Евгений Плющен...
# 2        4100  Обезьяна бросилась на жительницу индийского ок...
# 3        2292  Пользователи Twitter поспорили о реакции интер...
# 4        3365  Россиянка по имени Юлия на днях вернулась из И...
#
#            rubric
# 0      Нацпроекты
# 1           Спорт
# 2        Из жизни
# 3  Интернет и СМИ
# 4          Россия

# %%
train_df["rubric"].value_counts()
# Out:
# rubric
# Россия               635
# Мир                  502
# Спорт                346
# Экономика            294
# Бывший СССР          276
# Силовые структуры    154
# Интернет и СМИ       148
# Наука и техника      146
# Культура             144
# Из жизни             138
# Путешествия          128
# Ценности              99
# Дом                   86
# Нацпроекты            37
# 69-я параллель        19
# Name: count, dtype: int64

# %%
train_df.columns
# Out:
# Index(['Unnamed: 0', 'text', 'rubric'], dtype='str')

# %%
train_df["rubric"].value_counts()
# Out:
# rubric
# Россия               635
# Мир                  502
# Спорт                346
# Экономика            294
# Бывший СССР          276
# Силовые структуры    154
# Интернет и СМИ       148
# Наука и техника      146
# Культура             144
# Из жизни             138
# Путешествия          128
# Ценности              99
# Дом                   86
# Нацпроекты            37
# 69-я параллель        19
# Name: count, dtype: int64

# %%
train_df["text"].str.split().str.len().describe()
# Out:
# count    3152.000000
# mean      184.371827
# std       160.014043
# min        44.000000
# 25%       131.000000
# 50%       162.000000
# 75%       201.000000
# max      3857.000000
# Name: text, dtype: float64
